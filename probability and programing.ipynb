# %% [markdown]
# ## מגישה: מלי בלוך

# %% [markdown]
# ### שאלות הסתברות

# %% [markdown]
# ![%D7%A9%D7%90%D7%9C%D7%95%D7%AA%20%D7%94%D7%A1%D7%AA%D7%91%D7%A8%D7%95%D7%AA.jpg](attachment:%D7%A9%D7%90%D7%9C%D7%95%D7%AA%20%D7%94%D7%A1%D7%AA%D7%91%D7%A8%D7%95%D7%AA.jpg)

# %% [markdown]
# ### שאלות פייתון ופנדס

# %% [markdown]
# 1.	כתוב תוכנית בשפת פייתון אשר מקבלת מספר בבסיס 10 ומדפיסה את המספר בכל הבסיסים האחרים (בסיס 2, בסיס 8 ובסיס 16).

# %%
print('Enter a number:')
num = int(input())
print('Number in binary: ',bin(num)[2:])
print('Number in octal: ',oct(num)[2:])
print('Number in hexadecimal: ',hex(num)[2:])
# Out:
# Enter a number:
# 6
# Number in binary:  110
# Number in octal:  6
# Number in hexadecimal:  6

# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/Mali/Desktop/titles.csv',index_col=None)
cast=pd.read_csv('C:/Users/Mali/Downloads/cast.csv',index_col=None)

# %% [markdown]
# 1.	How many movies have the title "Hamlet"?

# %%
len(df[df.title == 'Hamlet'])
# Out:
# 19

# %% [markdown]
# 2.	List all of the "Treasure Island" movies from earliest to most recent.

# %%
df[df.title == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 191379  Treasure Island  1918
# 47769   Treasure Island  1920
# 192917  Treasure Island  1934
# 90175   Treasure Island  1950
# 104714  Treasure Island  1972
# 103646  Treasure Island  1973
# 190792  Treasure Island  1985
# 166675  Treasure Island  1999

# %% [markdown]
# 3.	How many roles were credited in the silent 1921 version of Hamlet?

# %%
len(cast[(cast.title == 'Hamlet') & (cast.year == 1921)])
# Out:
# 9

# %% [markdown]
# 4.	Use groupby() to plot the number of "Hamlet" films made each decade

# %%
df['decade'] = df.year // 10 * 10
df[df.title=='Hamlet'].groupby('decade').size().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='decade'>

# %% [markdown]
# 5.	How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
cast[(cast.year//10==195)&(cast.n==1)].groupby(['year','type']).type.value_counts()
# Out:
# year  type     type
# 1950  actor    actor      604
#       actress  actress    271
# 1951  actor    actor      633
#       actress  actress    272
# 1952  actor    actor      591
#       actress  actress    284
# 1953  actor    actor      634
#       actress  actress    290
# 1954  actor    actor      626
#       actress  actress    298
# 1955  actor    actor      606
#       actress  actress    264
# 1956  actor    actor      614
#       actress  actress    288
# 1957  actor    actor      708
#       actress  actress    284
# 1958  actor    actor      694
#       actress  actress    275
# 1959  actor    actor      678
#       actress  actress    287
# Name: type, dtype: int64

# %% [markdown]
# 6.	List the 10 actors/actresses that have the most leading roles (n=1) since the 1990's.

# %%
cast[(cast['n']==1) & (cast['year']>=1990)].groupby(['name']).name.value_counts().sort_values(ascending=False).head(10)
# Out:
# name                name
# Mohanlal            Mohanlal              126
# Mammootty           Mammootty             118
# Akshay Kumar        Akshay Kumar           87
# Jayaram             Jayaram                76
# Andy Lau            Andy Lau               72
# Ajay Devgn          Ajay Devgn             69
# Amitabh Bachchan    Amitabh Bachchan       68
# Eric Roberts        Eric Roberts           68
# Nagarjuna Akkineni  Nagarjuna Akkineni     60
# Dilip               Dilip                  59
# Name: name, dtype: int64

# %% [markdown]
# 7.	List, in order by year, each of the films in which Frank Oz has played more than 1 role

# %%
frank = cast[cast.name=='Frank Oz'].groupby(['year','title']).size()
frank[frank>1]
# Out:
# year  title
# 1979  The Muppet Movie                            8
# 1981  An American Werewolf in London              2
#       The Great Muppet Caper                      6
# 1982  The Dark Crystal                            2
# 1984  The Muppets Take Manhattan                  7
# 1985  Sesame Street Presents: Follow that Bird    3
# 1992  The Muppet Christmas Carol                  7
# 1996  Muppet Treasure Island                      4
# 1999  Muppets from Space                          4
#       The Adventures of Elmo in Grouchland        3
# dtype: int64
